# %%
import pandas as pd
import streamlit as st
from sodapy import Socrata

# %%
url = "data.cityofchicago.org"
resource = "v6vf-nfxy"
client = Socrata(url, app_token=token)

# %%
## AAE: Water on street complaint
## AAF: Water in Basement Complaint
results = client.get("v6vf-nfxy", zip_code="60629", sr_short_code="AAE")

# %%
df = pd.DataFrame.from_records(results)
df
# Out:
#          sr_number                    sr_type sr_short_code  \
# 0    SR24-00421651  Water On Street Complaint           AAE
# 1    SR24-01050138  Water On Street Complaint           AAE
# 2    SR24-01131358  Water On Street Complaint           AAE
# 3    SR24-00412790  Water On Street Complaint           AAE
# 4    SR24-00599413  Water On Street Complaint           AAE
# ..             ...                        ...           ...
# 995  SR22-00730636  Water On Street Complaint           AAE
# 996  SR22-00731016  Water On Street Complaint           AAE
# 997  SR22-00731034  Water On Street Complaint           AAE
# 998  SR22-00731386  Water On Street Complaint           AAE
# 999  SR22-00731674  Water On Street Complaint           AAE
#
#          created_department                      owner_department     status  \
# 0         311 City Services  DWM - Department of Water Management  Completed
# 1         311 City Services  DWM - Department of Water Management  Completed
# ...
