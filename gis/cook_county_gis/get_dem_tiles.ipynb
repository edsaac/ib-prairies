# %%
import requests
from itertools import batched
from pathlib import Path
import shutil

COOK_COUNTY_GIS_URL = (
    "https://gis.cookcountyil.gov/imagery/rest/services/DEM2022/ImageServer"
)

# %% [markdown]
# # Cook County Digital Elevation Model (DEM)
#
# Tiles index:
# > https://hub-cookcountyil.opendata.arcgis.com/datasets/cookcountyil::aerial-imagery-reference-tiles/explore
#
# Query Service:
# > https://gis.cookcountyil.gov/imagery/rest/services/DEM2022/ImageServer/query
#
# Download:
# > https://gis.cookcountyil.gov/imagery/rest/services/DEM2022/ImageServer/download

# %%
def get_tile_id(tile_number: list[str]):
    # SQL Query
    str_tiles = ",".join([f"'dem_{s}'" for s in tile_number])
    sql_query = f"Name IN ({str_tiles})"
    
    # REST API endpoint
    url = f"{COOK_COUNTY_GIS_URL}/query"

    # Adding parameters to query
    payload = dict(
        where=sql_query,
        returnIdsOnly=True,
        returnGeometry=False,
        f="pjson",
    )

    # A get request to the API
    response = requests.get(url, params=payload)
    response.raise_for_status()
    return response.json()

# %%
get_tile_id(('16507850', '15507900',))
# Out:
# {'objectIdFieldName': 'OBJECTID', 'objectIds': [3839, 4212]}

# %%
def get_tif_download_urls(tile_id):

    # REST API endpoint
    url = url = f"{COOK_COUNTY_GIS_URL}/download"

    # Adding parameters to query
    payload = dict(rasterIds=tile_id, format="tif", f="pjson")

    # A get request to the API
    response = requests.get(url, params=payload)
    response.raise_for_status()
    return response.json()

# %%
get_tif_download_urls(4212)
# Out:
# {'rasterFiles': [{'id': '.\\DEM_2022\\be_rasters\\dem_16507850.tif',
#    'size': 15582806,
#    'rasterIds': [4212]},
#   {'id': '.\\DEM_2022\\be_rasters\\dem_16507850.tif.ovr',
#    'size': 5025519,
#    'rasterIds': [4212]},
#   {'id': '.\\DEM_2022\\be_rasters\\dem_16507850.tif.aux.xml',
#    'size': 2445,
#    'rasterIds': [4212]}]}

# %%
WORKING_DIR = Path("Edwin")
PATH_LIST_TILES = WORKING_DIR/"tile_list"
FINAL_DEST = Path("/media/edwin/LaCie/Cook County Elevation/DEM_2022")

# %%
path_list_ids = WORKING_DIR/"tile_ids"
(download_dir := WORKING_DIR/"download").mkdir(exist_ok=True)

# %%
with open(PATH_LIST_TILES) as f:
    tile_list = list(set([x.strip() for x in f.readlines()]))

# %%
tile_ids = []

for tile_chunck in batched(tile_list, 20):
    response = get_tile_id(tile_chunck)
    tile_ids += response['objectIds']

# %%
# Write to a file the list of tiles ids
with open(path_list_ids, "w") as f:
    for tile_id in tile_ids:
        f.write(str(tile_id) + "\n")

# %%
for tile_id in tile_ids:
    for raster_json in get_tif_download_urls(tile_id)['rasterFiles']:
        raster_url = raster_json['id']
        raster_file = download_dir/(raster_url.rpartition('\\')[-1])
        raster_id = raster_json['rasterIds'][0]
        
        if (FINAL_DEST/raster_file.name).exists():
            print(f"Skipping {raster_file.name}, already downloaded")
    
        else:
            print(f"Downloading {raster_file}")

            payload = dict(
                id=raster_url,
                rasterId=raster_id,
            )

            r = requests.get(f"{COOK_COUNTY_GIS_URL}/file?", params=payload, stream=True)
            r.raise_for_status()
        
            with open(raster_file, 'wb') as f:
                f.write(r.content)

    
            shutil.move(raster_file, FINAL_DEST)
            print(f"Downloaded {raster_file.name}")
# Out:
# Downloading Edwin/download/dem_14507850.tif
# Downloaded dem_14507850.tif
# Downloading Edwin/download/dem_14507850.tif.ovr
# Downloaded dem_14507850.tif.ovr
# Downloading Edwin/download/dem_14507850.tif.aux.xml
# Downloaded dem_14507850.tif.aux.xml
# Downloading Edwin/download/dem_14507975.tif
# Downloaded dem_14507975.tif
# Downloading Edwin/download/dem_14507975.tif.ovr
# Downloaded dem_14507975.tif.ovr
# Downloading Edwin/download/dem_14507975.tif.aux.xml
# Downloaded dem_14507975.tif.aux.xml
# Downloading Edwin/download/dem_14508000.tif
# Downloaded dem_14508000.tif
# Downloading Edwin/download/dem_14508000.tif.ovr
# Downloaded dem_14508000.tif.ovr
# Downloading Edwin/download/dem_14508000.tif.aux.xml
# Downloaded dem_14508000.tif.aux.xml
# Downloading Edwin/download/dem_14757900.tif
# Downloaded dem_14757900.tif
# Downloading Edwin/download/dem_14757900.tif.ovr
# Downloaded dem_14757900.tif.ovr
# Downloading Edwin/download/dem_14757900.tif.aux.xml
# Downloaded dem_14757900.tif.aux.xml
# Downloading Edwin/download/dem_14757975.tif
# Downloaded dem_14757975.tif
# Downloading Edwin/download/dem_14757975.tif.ovr
# Downloaded dem_14757975.tif.ovr
# Downloading Edwin/download/dem_14757975.tif.aux.xml
# Downloaded dem_14757975.tif.aux.xml
# Downloading Edwin/download/dem_14758000.tif
# Downloaded dem_14758000.tif
# Downloading Edwin/download/dem_14758000.tif.ovr
# Downloaded dem_14758000.tif.ovr
# Downloading Edwin/download/dem_14758000.tif.aux.xml
# Downloaded dem_14758000.tif.aux.xml
# Downloading Edwin/download/dem_15007900.tif
# Downloaded dem_15007900.tif
# Downloading Edwin/download/dem_15007900.tif.ovr
# Downloaded dem_15007900.tif.ovr
# Downloading Edwin/download/dem_15007900.tif.aux.xml
# Downloaded dem_15007900.tif.aux.xml
# Downloading Edwin/download/dem_15007975.tif
# Downloaded dem_15007975.tif
# Downloading Edwin/download/dem_15007975.tif.ovr
# Downloaded dem_15007975.tif.ovr
# Downloading Edwin/download/dem_15007975.tif.aux.xml
# Downloaded dem_15007975.tif.aux.xml
# Downloading Edwin/download/dem_15257875.tif
# Downloaded dem_15257875.tif
# Downloading Edwin/download/dem_15257875.tif.ovr
# Downloaded dem_15257875.tif.ovr
# Downloading Edwin/download/dem_15257875.tif.aux.xml
# Downloaded dem_15257875.tif.aux.xml
# Downloading Edwin/download/dem_15257950.tif
# Downloaded dem_15257950.tif
# Downloading Edwin/download/dem_15257950.tif.ovr
# Downloaded dem_15257950.tif.ovr
# Downloading Edwin/download/dem_15257950.tif.aux.xml
# Downloaded dem_15257950.tif.aux.xml
# Downloading Edwin/download/dem_15507900.tif
# Downloaded dem_15507900.tif
# Downloading Edwin/download/dem_15507900.tif.ovr
# Downloaded dem_15507900.tif.ovr
# Downloading Edwin/download/dem_15507900.tif.aux.xml
# Downloaded dem_15507900.tif.aux.xml
# Downloading Edwin/download/dem_15508000.tif
# Downloaded dem_15508000.tif
# Downloading Edwin/download/dem_15508000.tif.ovr
# Downloaded dem_15508000.tif.ovr
# Downloading Edwin/download/dem_15508000.tif.aux.xml
# Downloaded dem_15508000.tif.aux.xml
# Downloading Edwin/download/dem_15757875.tif
# Downloaded dem_15757875.tif
# Downloading Edwin/download/dem_15757875.tif.ovr
# Downloaded dem_15757875.tif.ovr
# Downloading Edwin/download/dem_15757875.tif.aux.xml
# Downloaded dem_15757875.tif.aux.xml
# Downloading Edwin/download/dem_15758025.tif
# Downloaded dem_15758025.tif
# Downloading Edwin/download/dem_15758025.tif.ovr
# Downloaded dem_15758025.tif.ovr
# Downloading Edwin/download/dem_15758025.tif.aux.xml
# Downloaded dem_15758025.tif.aux.xml
# Downloading Edwin/download/dem_16007875.tif
# Downloaded dem_16007875.tif
# Downloading Edwin/download/dem_16007875.tif.ovr
# Downloaded dem_16007875.tif.ovr
# Downloading Edwin/download/dem_16007875.tif.aux.xml
# Downloaded dem_16007875.tif.aux.xml
# Downloading Edwin/download/dem_16007925.tif
# Downloaded dem_16007925.tif
# Downloading Edwin/download/dem_16007925.tif.ovr
# Downloaded dem_16007925.tif.ovr
# Downloading Edwin/download/dem_16007925.tif.aux.xml
# Downloaded dem_16007925.tif.aux.xml
# Downloading Edwin/download/dem_16257900.tif
# Downloaded dem_16257900.tif
# Downloading Edwin/download/dem_16257900.tif.ovr
# Downloaded dem_16257900.tif.ovr
# Downloading Edwin/download/dem_16257900.tif.aux.xml
# Downloaded dem_16257900.tif.aux.xml
# Downloading Edwin/download/dem_16258000.tif
# Downloaded dem_16258000.tif
# Downloading Edwin/download/dem_16258000.tif.ovr
# Downloaded dem_16258000.tif.ovr
# Downloading Edwin/download/dem_16258000.tif.aux.xml
# Downloaded dem_16258000.tif.aux.xml
# Downloading Edwin/download/dem_16258050.tif
# Downloaded dem_16258050.tif
# Downloading Edwin/download/dem_16258050.tif.ovr
# Downloaded dem_16258050.tif.ovr
# Downloading Edwin/download/dem_16258050.tif.aux.xml
# Downloaded dem_16258050.tif.aux.xml
# Downloading Edwin/download/dem_16508050.tif
# Downloaded dem_16508050.tif
# Downloading Edwin/download/dem_16508050.tif.ovr
# Downloaded dem_16508050.tif.ovr
# Downloading Edwin/download/dem_16508050.tif.aux.xml
# Downloaded dem_16508050.tif.aux.xml
# Downloading Edwin/download/dem_14507950.tif
# Downloaded dem_14507950.tif
# Downloading Edwin/download/dem_14507950.tif.ovr
# Downloaded dem_14507950.tif.ovr
# Downloading Edwin/download/dem_14507950.tif.aux.xml
# Downloaded dem_14507950.tif.aux.xml
# Downloading Edwin/download/dem_14508025.tif
# Downloaded dem_14508025.tif
# Downloading Edwin/download/dem_14508025.tif.ovr
# Downloaded dem_14508025.tif.ovr
# Downloading Edwin/download/dem_14508025.tif.aux.xml
# Downloaded dem_14508025.tif.aux.xml
# Downloading Edwin/download/dem_14757875.tif
# Downloaded dem_14757875.tif
# Downloading Edwin/download/dem_14757875.tif.ovr
# Downloaded dem_14757875.tif.ovr
# Downloading Edwin/download/dem_14757875.tif.aux.xml
# Downloaded dem_16257950.tif.ovr
# Downloading Edwin/download/dem_16257950.tif.aux.xml
# Downloaded dem_16257950.tif.aux.xml
# Downloading Edwin/download/dem_16258025.tif
# Downloaded dem_16258025.tif
# Downloading Edwin/download/dem_16258025.tif.ovr
# Downloaded dem_16258025.tif.ovr
# Downloading Edwin/download/dem_16258025.tif.aux.xml
# Downloaded dem_16258025.tif.aux.xml
# Downloading Edwin/download/dem_16507850.tif
# Downloaded dem_16507850.tif
# Downloading Edwin/download/dem_16507850.tif.ovr
# Downloaded dem_16507850.tif.ovr
# Downloading Edwin/download/dem_16507850.tif.aux.xml
# Downloaded dem_16507850.tif.aux.xml
# Downloading Edwin/download/dem_16507875.tif
# Downloaded dem_16507875.tif
# Downloading Edwin/download/dem_16507875.tif.ovr
# Downloaded dem_16507875.tif.ovr
# Downloading Edwin/download/dem_16507875.tif.aux.xml
# Downloaded dem_16507875.tif.aux.xml
# Downloading Edwin/download/dem_16507900.tif
# Downloaded dem_16507900.tif
# Downloading Edwin/download/dem_16507900.tif.ovr
# Downloaded dem_16507900.tif.ovr
# Downloading Edwin/download/dem_16507900.tif.aux.xml
# Downloaded dem_16507900.tif.aux.xml
# Downloading Edwin/download/dem_16508000.tif
# Downloaded dem_16508000.tif
# Downloading Edwin/download/dem_16508000.tif.ovr
# Downloaded dem_16508000.tif.ovr
# Downloading Edwin/download/dem_16508000.tif.aux.xml
# Downloaded dem_16508000.tif.aux.xml
# Downloading Edwin/download/dem_14507875.tif
# Downloaded dem_14507875.tif
# Downloading Edwin/download/dem_14507875.tif.ovr
# Downloaded dem_14507875.tif.ovr
# Downloading Edwin/download/dem_14507875.tif.aux.xml
# Downloaded dem_14507875.tif.aux.xml
# Downloading Edwin/download/dem_14507900.tif
# Downloaded dem_14507900.tif
# Downloading Edwin/download/dem_14507900.tif.ovr
# Downloaded dem_14507900.tif.ovr
# Downloading Edwin/download/dem_14507900.tif.aux.xml
# Downloaded dem_14507900.tif.aux.xml
# Downloading Edwin/download/dem_14508050.tif
# Downloaded dem_14508050.tif
# Downloading Edwin/download/dem_14508050.tif.ovr
# Downloaded dem_14508050.tif.ovr
# Downloading Edwin/download/dem_14508050.tif.aux.xml
# Downloaded dem_14508050.tif.aux.xml
# Downloading Edwin/download/dem_14758025.tif
# Downloaded dem_14758025.tif
# Downloading Edwin/download/dem_14758025.tif.ovr
# Downloaded dem_14758025.tif.ovr
# Downloading Edwin/download/dem_14758025.tif.aux.xml
# Downloaded dem_14758025.tif.aux.xml
# Downloading Edwin/download/dem_14758050.tif
# Downloaded dem_14758050.tif
# Downloading Edwin/download/dem_14758050.tif.ovr
# Downloaded dem_14758050.tif.ovr
# Downloading Edwin/download/dem_14758050.tif.aux.xml
# Downloaded dem_14758050.tif.aux.xml
# Downloading Edwin/download/dem_15007850.tif
# Downloaded dem_15007850.tif
# Downloading Edwin/download/dem_15007850.tif.ovr
# Downloaded dem_15007850.tif.ovr
# Downloading Edwin/download/dem_15007850.tif.aux.xml
# Downloaded dem_15007850.tif.aux.xml
# Downloading Edwin/download/dem_15757925.tif.ovr
# Downloaded dem_15757925.tif.ovr
# Downloading Edwin/download/dem_15757925.tif.aux.xml
# Downloaded dem_15757925.tif.aux.xml
# Downloading Edwin/download/dem_15757975.tif
# Downloaded dem_15757975.tif
# Downloading Edwin/download/dem_15757975.tif.ovr
# Downloaded dem_15757975.tif.ovr
# Downloading Edwin/download/dem_15757975.tif.aux.xml
# Downloaded dem_15757975.tif.aux.xml
# Downloading Edwin/download/dem_15758000.tif
# Downloaded dem_15758000.tif
# Downloading Edwin/download/dem_15758000.tif.ovr
# Downloaded dem_15758000.tif.ovr
# Downloading Edwin/download/dem_15758000.tif.aux.xml
# Downloaded dem_15758000.tif.aux.xml
# Downloading Edwin/download/dem_16007900.tif
# Downloaded dem_16007900.tif
# Downloading Edwin/download/dem_16007900.tif.ovr
# Downloaded dem_16007900.tif.ovr
# Downloading Edwin/download/dem_16007900.tif.aux.xml
# Downloaded dem_16007900.tif.aux.xml
# Downloading Edwin/download/dem_16007950.tif
# Downloaded dem_16007950.tif
# Downloading Edwin/download/dem_16007950.tif.ovr
# Downloaded dem_16007950.tif.ovr
# Downloading Edwin/download/dem_16007950.tif.aux.xml
# Downloaded dem_16007950.tif.aux.xml
# Downloading Edwin/download/dem_16007975.tif
# Downloaded dem_16007975.tif
# Downloading Edwin/download/dem_16007975.tif.ovr
# Downloaded dem_16007975.tif.ovr
# Downloading Edwin/download/dem_16007975.tif.aux.xml
# Downloaded dem_16007975.tif.aux.xml
# Downloading Edwin/download/dem_16008025.tif
# Downloaded dem_16008025.tif
# Downloading Edwin/download/dem_16008025.tif.ovr
# Downloaded dem_16008025.tif.ovr
# Downloading Edwin/download/dem_16008025.tif.aux.xml
# Downloaded dem_16008025.tif.aux.xml
# Downloading Edwin/download/dem_16257850.tif
# Downloaded dem_16257850.tif
# Downloading Edwin/download/dem_16257850.tif.ovr
# Downloaded dem_16257850.tif.ovr
# Downloading Edwin/download/dem_16257850.tif.aux.xml
# Downloaded dem_16257850.tif.aux.xml
# Downloading Edwin/download/dem_16257925.tif
# Downloaded dem_16257925.tif
# Downloading Edwin/download/dem_16257925.tif.ovr
# Downloaded dem_16257925.tif.ovr
# Downloading Edwin/download/dem_16257925.tif.aux.xml
# Downloaded dem_16257925.tif.aux.xml
# Downloading Edwin/download/dem_16257975.tif
# Downloaded dem_16257975.tif
# Downloading Edwin/download/dem_16257975.tif.ovr
# Downloaded dem_16257975.tif.ovr
# Downloading Edwin/download/dem_16257975.tif.aux.xml
# Downloaded dem_16257975.tif.aux.xml
# Downloading Edwin/download/dem_16507975.tif
# Downloaded dem_16507975.tif
# Downloading Edwin/download/dem_16507975.tif.ovr
# Downloaded dem_16507975.tif.ovr
# Downloading Edwin/download/dem_16507975.tif.aux.xml
# Downloaded dem_16507975.tif.aux.xml
# Downloading Edwin/download/dem_15257850.tif
# Downloaded dem_15257850.tif
# Downloading Edwin/download/dem_15257850.tif.ovr
# Downloaded dem_15257850.tif.ovr
# Downloading Edwin/download/dem_15257850.tif.aux.xml
# Downloaded dem_15257850.tif.aux.xml
