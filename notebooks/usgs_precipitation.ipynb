# %%
import dataretrieval.nwis as nwis
import folium

# specify the USGS site code for which we want data.
sites = ['413548087395901', '413516087442101']

# get basic info about the site
df3 = nwis.get_record(sites=sites, service='site')

df3
# Out:
#   agency_cd          site_no  \
# 0      USGS  413516087442101
# 1      USGS  413548087395901
#
#                                           station_nm site_tp_cd  lat_va  \
# 0                        RAIN GAGE AT OAK FOREST, IL         AT  413516
# 1  RAIN GAGE AT CALUMET UNION DR CANAL NR MARKHAM...         AT  413548
#
#    long_va  dec_lat_va  dec_long_va coord_meth_cd coord_acy_cd  ...  \
# 0   874421   41.587778   -87.739167             N            S  ...
# 1   873959   41.596667   -87.666389             M            S  ...
#
#   local_time_fg reliability_cd  gw_file_cd  nat_aqfr_cd  aqfr_cd aqfr_type_cd  \
# 0             N            NaN         NaN          NaN      NaN          NaN
# 1             N            NaN         NaN          NaN      NaN          NaN
#
#   well_depth_va hole_depth_va  depth_src_cd  project_no
# 0           NaN           NaN           NaN      CAWS00
# 1           NaN           NaN           NaN       001UM
#
# [2 rows x 42 columns]

# %%
m = folium.Map(location=[df3['dec_lat_va'].mean(), df3['dec_long_va'].mean()], zoom_start=13)

# %%
for idx, site in df3.iterrows():
    folium.Marker([site['dec_lat_va'], site['dec_long_va']], popup=site['station_nm'], tooltip=site['station_nm']).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# get instantaneous values (iv)
df = nwis.get_record(sites=site, service='iv', start='2019-11-27', end='2018-01-01')

# %%
# get water quality samples (qwdata)

df2 = nwis.get_record(sites=site, service='qwdata', start='2017-12-31', end='2018-01-01')
